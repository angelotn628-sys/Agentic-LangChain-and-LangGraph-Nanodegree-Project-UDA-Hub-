# %%
import sqlite3

conn = sqlite3.connect("udahub.db")
conn.row_factory = sqlite3.Row
cursor = conn.cursor()

cursor.execute("""
    SELECT name
    FROM sqlite_master
    WHERE type='table'
    ORDER BY name;
""")
tables = [row["name"] for row in cursor.fetchall()]

for table_name in tables:
    print(f"\n=== TABLE: {table_name} ===")

    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()

    print("Columns:")
    for col in columns:
        col = dict(col)
        print(
            f"  - name={col['name']}, "
            f"type={col['type']}, "
            f"notnull={col['notnull']}, "
            f"pk={col['pk']}"
        )

    cursor.execute(f"SELECT * FROM {table_name};")
    rows = cursor.fetchall()

    print("Rows:")
    if rows:
        for row in rows:
            print(f"  {dict(row)}")
    else:
        print("  (no rows)")

conn.close()
# Out:
# === TABLE: accounts ===
# Columns:
#   - name=account_id, type=VARCHAR, notnull=1, pk=1
#   - name=account_name, type=VARCHAR, notnull=1, pk=0
#   - name=created_at, type=DATETIME, notnull=0, pk=0
#   - name=updated_at, type=DATETIME, notnull=0, pk=0
# Rows:
#   {'account_id': 'cultpass', 'account_name': 'CultPass Card', 'created_at': '2026-05-27 21:26:45', 'updated_at': '2026-05-27 21:26:45'}
#
# === TABLE: knowledge ===
# Columns:
#   - name=article_id, type=VARCHAR, notnull=1, pk=1
#   - name=account_id, type=VARCHAR, notnull=1, pk=0
#   - name=title, type=VARCHAR, notnull=1, pk=0
#   - name=content, type=TEXT, notnull=1, pk=0
#   - name=tags, type=TEXT, notnull=0, pk=0
#   - name=created_at, type=DATETIME, notnull=0, pk=0
#   - name=updated_at, type=DATETIME, notnull=0, pk=0
# Rows:
#   {'article_id': '9afc81d7-42af-44bb-afbd-58621cbe38ea', 'account_id': 'cultpass', 'title': 'How to Reserve a Spot for an Event', 'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."', 'tags': 'reservation, events, booking, attendance', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'df3dce04-0f68-4cca-b6c8-f98c7b71af16', 'account_id': 'cultpass', 'title': "What's Included in a CultPass Subscription", 'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."', 'tags': 'subscription, benefits, pricing, access', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '6b0a93c7-3507-4140-b3ee-99c787da5980', 'account_id': 'cultpass', 'title': 'How to Cancel or Pause a Subscription', 'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."', 'tags': 'cancelation, pause, subscription, billing', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '7476fe14-2cd8-4859-a9ff-bc7d163f5f6e', 'account_id': 'cultpass', 'title': 'How to Handle Login Issues?', 'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."', 'tags': 'login, password, access, escalation', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '2b5c5d68-2165-4b1c-9228-abde05d2449b', 'account_id': 'cultpass', 'title': 'App Crashes on Launch', 'content': 'If a user reports that the CultPass app crashes immediately after opening, ask them to fully close and reopen the app, confirm they are using the latest version, and restart their device. If the issue continues, suggest reinstalling the app. If the crash persists after reinstalling, escalate the issue to human support. Suggested phrasing: "Please try closing and reopening the app, make sure it is updated to the latest version, and restart your device. If the issue continues, reinstalling the app may help."', 'tags': 'technical issue, app crash, troubleshooting, mobile', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '9c4ba8a5-63d4-4093-8dba-c426d0e15e9f', 'account_id': 'cultpass', 'title': 'QR Code Not Displaying for Reservation', 'content': 'If a user cannot see the QR code for an upcoming reservation, ask them to refresh the reservation page, confirm the booking is still active, and log out and back in to the app. Also suggest updating the app to the latest version. If the QR code still does not appear, escalate to human support. Suggested phrasing: "Try refreshing the reservation page or logging out and back in. If the QR code still does not appear, please contact support for further help."', 'tags': 'technical issue, qr code, reservation, app', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'bcd85883-b24f-42fd-a2b3-2c628fabfd47', 'account_id': 'cultpass', 'title': 'App Loading Slowly or Freezing', 'content': 'If a user says the app is slow, freezing, or unresponsive, ask them to check their internet connection, switch between Wi-Fi and mobile data if possible, and close other background apps. Suggest updating the app and restarting the device. If the issue continues across multiple sessions, escalate to support. Suggested phrasing: "Please check your connection, restart the app, and make sure you are using the latest version. If the issue continues, support can investigate further."', 'tags': 'technical issue, performance, app, troubleshooting', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '82aba882-2f39-4543-97ae-79e44744afee', 'account_id': 'cultpass', 'title': 'Unable to Log In After Multiple Attempts', 'content': 'If a user cannot log in after several attempts, ask them to verify their email and password, use the \'Forgot Password\' option if needed, and make sure they are signing in with the correct account. If they still cannot access their account after resetting the password, escalate to human support. Suggested phrasing: "Please double-check your login details or use the \'Forgot Password\' option. If you still cannot sign in after resetting your password, support can help investigate."', 'tags': 'technical issue, login, access, troubleshooting', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '4983276a-7d71-4597-8d90-bde7d7d619bb', 'account_id': 'cultpass', 'title': 'How to Update Payment Method', 'content': 'If a user needs to change their payment method, direct them to the CultPass app and ask them to go to \'My Account\' > \'Billing\' > \'Update Payment Method\'. They should enter the new payment details and save the changes before exiting. Suggested phrasing: "You can update your payment details anytime in the app under \'My Account\' and \'Billing\'. Just select \'Update Payment Method\' and save your changes."', 'tags': 'billing, payment method, card, subscription', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'eaa6ddd5-f441-4dd7-bd8c-6bf866504758', 'account_id': 'cultpass', 'title': 'Payment Failed During Subscription Renewal', 'content': 'If a user\'s subscription renewal payment fails, ask them to confirm their card details are correct, check whether the card has expired, and verify that sufficient funds are available. Suggest retrying after a few minutes. If the issue continues, recommend contacting their bank and then support if needed. Suggested phrasing: "Please confirm your card details and make sure your payment method is active. If the issue continues after retrying, your bank may be able to provide more information."', 'tags': 'billing, payment failure, renewal, troubleshooting', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'f79b9f27-1029-4073-9b2a-77d3e09ff631', 'account_id': 'cultpass', 'title': 'Duplicate Charge on Account', 'content': 'If a user reports being charged twice, acknowledge the concern and ask them to verify the transaction dates and amounts. Explain that temporary bank authorizations can sometimes appear as duplicate charges. If both charges remain posted after the pending period, escalate the case to human support for review. Suggested phrasing: "Sometimes a temporary bank authorization can look like a duplicate charge. If both charges remain posted, please contact support so we can investigate."', 'tags': 'billing, duplicate charge, payment, escalation', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'b37f1adb-c1f4-4d54-9d52-3b1f9a7dcaad', 'account_id': 'cultpass', 'title': 'How to Redeem a Promo Code', 'content': 'If a user has a promo code, direct them to the CultPass app and ask them to go to \'My Account\' > \'Promotions\'. They should enter the code exactly as provided and tap \'Apply\'. If the code does not work, ask them to confirm it has not expired and that it matches the offer terms. Suggested phrasing: "You can redeem your promo code in the app under \'My Account\' and \'Promotions\'. Enter the code exactly as shown and tap \'Apply\'."', 'tags': 'billing, promo code, discount, offers', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '54d86403-b5e3-4eb5-a383-8176b50f46a0', 'account_id': 'cultpass', 'title': 'How to Reset a Forgotten Password', 'content': 'If a user forgot their password, direct them to the login screen in the CultPass app or website and ask them to select \'Forgot Password\'. They should enter their registered email address and follow the reset link sent to their inbox. If they do not receive the email, ask them to check spam or junk folders before escalating. Suggested phrasing: "You can reset your password from the login screen by selecting \'Forgot Password\' and following the instructions sent to your email."', 'tags': 'account, password, login, access', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '1d422325-ba8c-48ed-952d-29db79516c24', 'account_id': 'cultpass', 'title': 'How to Change the Email on an Account', 'content': 'If a user wants to update their email address, direct them to the CultPass app and ask them to go to \'My Account\' > \'Profile Settings\' > \'Edit Email\'. They may need to verify the new email address before the change is completed. If they no longer have access to the old email, escalate to human support. Suggested phrasing: "You can update your email in the app under \'My Account\' and \'Profile Settings\'. If verification is required, please follow the instructions sent to your new email."', 'tags': 'account, email, profile, verification', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'f9c4f52f-27fc-4a46-82eb-1e3d3281e3c2', 'account_id': 'cultpass', 'title': 'How to Change Notification Preferences', 'content': 'If a user wants to manage notifications, direct them to \'My Account\' > \'Notification Settings\' in the CultPass app. From there, they can enable or disable reminders, promotions, and event alerts. Suggested phrasing: "You can manage your notification preferences in the app under \'My Account\' and \'Notification Settings\'. There you can choose which alerts you would like to receive."', 'tags': 'account, notifications, settings, preferences', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'f61d181b-4737-4e95-8ad0-11861c4d93d4', 'account_id': 'cultpass', 'title': 'How to Update Personal Profile Information', 'content': 'If a user notices incorrect personal details on their account, direct them to \'My Account\' > \'Profile Settings\', where they can update editable fields. If a field cannot be changed manually, escalate the issue to human support. Suggested phrasing: "You can update most personal details in the app under \'My Account\' and \'Profile Settings\'. If a field cannot be edited, support can help."', 'tags': 'account, profile, personal information, support', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '24f9a104-be60-409f-84e5-26dd5736e182', 'account_id': 'cultpass', 'title': 'How to View Upcoming Reservations', 'content': 'If a user wants to see their booked events, direct them to open the CultPass app and go to \'My Reservations\'. Upcoming experiences should be listed with the date, time, and QR code if available. Suggested phrasing: "You can view all your upcoming reservations in the app under \'My Reservations\', where you will also find your event details and QR codes."', 'tags': 'reservations, bookings, events, qr code', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '22354505-78eb-476d-8eba-ad0e5e271512', 'account_id': 'cultpass', 'title': 'How to Cancel an Event Reservation', 'content': 'If a user needs to cancel a reservation, ask them to open \'My Reservations\' in the app, select the event they want to cancel, and tap \'Cancel Reservation\'. Remind them that some events may have cancellation deadlines or restrictions. Suggested phrasing: "You can cancel a reservation from the \'My Reservations\' section of the app. Please note that some events may have cancellation deadlines."', 'tags': 'reservations, cancellation, booking, events', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': 'd619f164-627d-44d7-b904-e4dc5e0c6a29', 'account_id': 'cultpass', 'title': 'How to Confirm a Reservation Was Successful', 'content': 'If a user is unsure whether their booking went through, ask them to check \'My Reservations\' in the app and confirm whether the event appears with its details. They may also receive a confirmation email for some bookings. Suggested phrasing: "You can confirm your reservation by checking \'My Reservations\' in the app. If the event appears there, your booking was successful."', 'tags': 'reservations, confirmation, booking, events', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '53435075-ad09-4a77-baff-22439634b0c8', 'account_id': 'cultpass', 'title': 'How to Find Event Location Details', 'content': 'If a user asks where an event takes place, direct them to the reservation details page in the app, where the venue name, address, and start time should be listed. Recommend checking the map link before leaving. Suggested phrasing: "You can find the event location and timing in your reservation details within the app. We recommend checking the map link before heading out."', 'tags': 'reservations, event location, venue, booking', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '29159c45-7e00-4ced-a78e-7664be28307b', 'account_id': 'cultpass', 'title': 'How to Contact Human Support', 'content': 'If a user needs help beyond standard guidance, direct them to the support section in the CultPass app or website. Encourage them to include screenshots, booking details, and any relevant error messages when contacting support. Suggested phrasing: "If you need additional help, please contact our support team through the app\'s support section and include any relevant details or screenshots."', 'tags': 'support, escalation, contact, help', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '5cf681c5-5bb8-44ae-a764-22fa2e969238', 'account_id': 'cultpass', 'title': 'Refund Requests for Missed Events', 'content': 'If a user asks for a refund after missing an event, explain that refund eligibility depends on the event\'s cancellation and attendance policy. Ask them to review the event terms and contact support if they believe an exception applies. Suggested phrasing: "Refund eligibility for missed events depends on the event policy. Please review the event terms, and if you believe an exception applies, contact support for further review."', 'tags': 'support, refund, policy, events', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '52cf5862-3443-48cb-8b8c-0d43b6574b21', 'account_id': 'cultpass', 'title': 'What to Do If an Event Is Sold Out', 'content': 'If a user wants to book an event that is already sold out, explain that availability is limited and reservations are offered on a first-come, first-served basis. Encourage them to check back later in case spots open up or look for similar events in the app. Suggested phrasing: "This event is currently sold out. You can check back later in case availability changes or explore similar events in the app."', 'tags': 'support, sold out, availability, events', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#   {'article_id': '84b0a116-bc46-448a-af9d-d0d612e9c5ad', 'account_id': 'cultpass', 'title': 'Membership Access After Cancellation', 'content': 'If a user asks whether they can still use CultPass after canceling, explain that access usually remains active until the end of the current billing cycle unless otherwise stated in their plan terms. Encourage them to review their subscription details in \'Manage Plan\'. Suggested phrasing: "After cancellation, access usually continues until the end of your current billing period. You can review your plan details in \'Manage Plan\' for confirmation."', 'tags': 'support, cancellation, membership, policy', 'created_at': '2026-05-27 21:26:59', 'updated_at': '2026-05-27 21:26:59'}
#
# === TABLE: ticket_messages ===
# Columns:
#   - name=message_id, type=VARCHAR, notnull=1, pk=1
#   - name=ticket_id, type=VARCHAR, notnull=1, pk=0
#   - name=role, type=VARCHAR(6), notnull=1, pk=0
#   - name=content, type=TEXT, notnull=0, pk=0
#   - name=created_at, type=DATETIME, notnull=0, pk=0
# Rows:
#   {'message_id': '66c0ba17-2008-426d-984c-bcb3be9fd2ee', 'ticket_id': 'adbd8f56-6d55-456a-b5e0-cf5fa5b47f0d', 'role': 'user', 'content': "I can't log in to my Cultpass account.", 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '64e7fea4-689d-4f7b-8e29-9ca17fcb41b2', 'ticket_id': '6bd13a96-f04e-4211-b182-c9afddd1df32', 'role': 'user', 'content': 'I was charged twice for my monthly subscription.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '6e818dbc-cc06-499b-a4aa-4891d4f9c754', 'ticket_id': 'e88ef671-3e60-4371-b3e1-9b06b1b7640b', 'role': 'user', 'content': 'My reservation for yoga class disappeared from the app.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '628ae6be-f8eb-4d4d-875d-ae95b6f0679b', 'ticket_id': '4ed7fb1d-6959-4bb9-a583-b55edc5357df', 'role': 'user', 'content': 'I need to update the email address on my account.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '7bb85fe0-9b1d-4a55-82cb-614270bfe850', 'ticket_id': '0b47f45f-20b0-4be8-abc9-4643a446f61f', 'role': 'user', 'content': "My account says blocked and I don't know why.", 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '0877bf0e-e916-4357-8494-1b7375aba2b7', 'ticket_id': 'f0b9bd31-6e90-40c4-b8ca-e8f7c0df7d36', 'role': 'user', 'content': 'I canceled my membership but I still got billed.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '79a86ca6-ce4f-44a9-8514-89ea403b0e83', 'ticket_id': '1c25bd85-80fb-43e3-8553-681d046c2dbc', 'role': 'user', 'content': 'The app crashes every time I try to book a class.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '716d49b6-9b55-413e-8789-e4a2cbc70b9d', 'ticket_id': '6dfe1375-0575-47fa-8af3-3b442c9b93a0', 'role': 'user', 'content': 'I forgot my password and the reset link is not working.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '69b9dc70-2637-4cfc-89f6-a55068a559e7', 'ticket_id': '810ab8ba-2b9a-4dd7-bd96-b8da0943f3f4', 'role': 'user', 'content': 'Can I transfer my reservation to a different time slot?', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': 'f462dfa5-d97f-494a-9802-71eac10c8d9a', 'ticket_id': '8a4861f6-cb21-4b63-a8a9-30ab5ef97d43', 'role': 'user', 'content': 'I was marked as a no-show even though I attended the class.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '3d9dcd4c-c536-4ccb-8a96-40b591cfb4fc', 'ticket_id': '0210a4e9-c32f-46b0-9756-63c10df03953', 'role': 'user', 'content': 'The promo code I received does not apply at checkout.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': 'a7102f15-1354-442c-8ac5-ce12fa170b3f', 'ticket_id': 'a406455a-d7f0-44a2-a1cc-18f3bb2f21ca', 'role': 'user', 'content': 'I want to pause my membership for one month.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '491f9673-9117-4cc9-aee5-63069443d1db', 'ticket_id': 'a525c713-7c8e-4cae-9a30-94287c257177', 'role': 'user', 'content': 'I booked a class by mistake and need to cancel it.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '5360e6fa-3e66-4089-9ff7-6466de67d27f', 'ticket_id': '1d79b94a-fb91-4478-8a0c-77d0391b56ba', 'role': 'user', 'content': 'My payment method keeps getting declined even though the card works elsewhere.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': 'c05c45c6-ac15-43db-a721-6118a259c03f', 'ticket_id': 'b91c28d0-8323-4dea-af3f-d8d5aaf05197', 'role': 'user', 'content': "I can't see my active subscription in the account dashboard.", 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '4e2ae336-8da8-4203-b7cb-69fbdf55bc07', 'ticket_id': '2e486748-0aa3-4236-a707-ce23f4045221', 'role': 'user', 'content': 'The instructor changed but I was not notified before the class.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': 'adcb27bf-9a82-48aa-b5b2-4feb40677a15', 'ticket_id': '60317982-a682-4565-8226-bd33b0b6aab1', 'role': 'user', 'content': 'I need a receipt for my last payment for reimbursement purposes.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': 'b2374ae4-18ca-4e8d-bdf4-068bbd5d39a1', 'ticket_id': '89057b01-61da-4413-b440-00bf432a6740', 'role': 'user', 'content': 'The location listed for my class seems incorrect.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': 'fb27bb00-6746-4a62-af57-22406b28704d', 'ticket_id': '65e0a350-6371-4004-b3dd-4181c42d817b', 'role': 'user', 'content': 'I want to know why my account was flagged for suspicious activity.', 'created_at': '2026-05-27 21:27:07'}
#   {'message_id': '25a1fb40-4d84-4641-9234-bfee291dd4f8', 'ticket_id': '739493bc-3f6e-4b34-80a0-e8e94cf92360', 'role': 'user', 'content': 'I was billed after my free trial ended without a reminder.', 'created_at': '2026-05-27 21:27:07'}
#
# === TABLE: ticket_metadata ===
# Columns:
#   - name=ticket_id, type=VARCHAR, notnull=1, pk=1
#   - name=status, type=VARCHAR, notnull=1, pk=0
#   - name=main_issue_type, type=VARCHAR, notnull=0, pk=0
#   - name=tags, type=TEXT, notnull=0, pk=0
#   - name=created_at, type=DATETIME, notnull=0, pk=0
#   - name=updated_at, type=DATETIME, notnull=0, pk=0
# Rows:
#   {'ticket_id': 'adbd8f56-6d55-456a-b5e0-cf5fa5b47f0d', 'status': 'open', 'main_issue_type': None, 'tags': 'login, access', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '6bd13a96-f04e-4211-b182-c9afddd1df32', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, duplicate charge', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'e88ef671-3e60-4371-b3e1-9b06b1b7640b', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, app issue', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '4ed7fb1d-6959-4bb9-a583-b55edc5357df', 'status': 'open', 'main_issue_type': None, 'tags': 'account, profile update', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '0b47f45f-20b0-4be8-abc9-4643a446f61f', 'status': 'open', 'main_issue_type': None, 'tags': 'account, blocked', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'f0b9bd31-6e90-40c4-b8ca-e8f7c0df7d36', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, cancellation', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '1c25bd85-80fb-43e3-8553-681d046c2dbc', 'status': 'open', 'main_issue_type': None, 'tags': 'app issue, booking', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '6dfe1375-0575-47fa-8af3-3b442c9b93a0', 'status': 'open', 'main_issue_type': None, 'tags': 'password reset, login', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '810ab8ba-2b9a-4dd7-bd96-b8da0943f3f4', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, schedule change', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '8a4861f6-cb21-4b63-a8a9-30ab5ef97d43', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, no-show', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '0210a4e9-c32f-46b0-9756-63c10df03953', 'status': 'open', 'main_issue_type': None, 'tags': 'promo code, checkout', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'a406455a-d7f0-44a2-a1cc-18f3bb2f21ca', 'status': 'open', 'main_issue_type': None, 'tags': 'membership, pause', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'a525c713-7c8e-4cae-9a30-94287c257177', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, cancellation', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '1d79b94a-fb91-4478-8a0c-77d0391b56ba', 'status': 'open', 'main_issue_type': None, 'tags': 'payment, billing', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'b91c28d0-8323-4dea-af3f-d8d5aaf05197', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, dashboard', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '2e486748-0aa3-4236-a707-ce23f4045221', 'status': 'open', 'main_issue_type': None, 'tags': 'class info, notification', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '60317982-a682-4565-8226-bd33b0b6aab1', 'status': 'open', 'main_issue_type': None, 'tags': 'receipt, billing', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '89057b01-61da-4413-b440-00bf432a6740', 'status': 'open', 'main_issue_type': None, 'tags': 'location, class info', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '65e0a350-6371-4004-b3dd-4181c42d817b', 'status': 'open', 'main_issue_type': None, 'tags': 'security, account', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '739493bc-3f6e-4b34-80a0-e8e94cf92360', 'status': 'open', 'main_issue_type': None, 'tags': 'free trial, billing', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#
# === TABLE: tickets ===
# Columns:
#   - name=ticket_id, type=VARCHAR, notnull=1, pk=1
#   - name=account_id, type=VARCHAR, notnull=1, pk=0
#   - name=user_id, type=VARCHAR, notnull=1, pk=0
#   - name=channel, type=VARCHAR, notnull=0, pk=0
#   - name=created_at, type=DATETIME, notnull=0, pk=0
# Rows:
#   {'ticket_id': 'adbd8f56-6d55-456a-b5e0-cf5fa5b47f0d', 'account_id': 'cultpass', 'user_id': 'b953ccbf-a292-420c-a3c3-918edf5b7d0f', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '6bd13a96-f04e-4211-b182-c9afddd1df32', 'account_id': 'cultpass', 'user_id': '862f59d9-987b-4bb3-bfe2-cfa16e3633d2', 'channel': 'email', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'e88ef671-3e60-4371-b3e1-9b06b1b7640b', 'account_id': 'cultpass', 'user_id': '910170dc-b46a-4400-a3e6-6f77c0c556bc', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '4ed7fb1d-6959-4bb9-a583-b55edc5357df', 'account_id': 'cultpass', 'user_id': '7f432978-c27a-474b-a0c8-664a36d06ffc', 'channel': 'web', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '0b47f45f-20b0-4be8-abc9-4643a446f61f', 'account_id': 'cultpass', 'user_id': 'ac57e665-bc84-4c9d-970d-e175ae9a45f9', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'f0b9bd31-6e90-40c4-b8ca-e8f7c0df7d36', 'account_id': 'cultpass', 'user_id': 'd35af443-1fe5-465e-94f6-bb89b16f21af', 'channel': 'email', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '1c25bd85-80fb-43e3-8553-681d046c2dbc', 'account_id': 'cultpass', 'user_id': '14f61f67-27be-427e-9bf4-361ed15f01bf', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '6dfe1375-0575-47fa-8af3-3b442c9b93a0', 'account_id': 'cultpass', 'user_id': 'd8733fe0-7b8a-4cce-b956-e16b3d74dd75', 'channel': 'web', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '810ab8ba-2b9a-4dd7-bd96-b8da0943f3f4', 'account_id': 'cultpass', 'user_id': 'ecd8defc-bf7f-437f-90be-e092f977d0b2', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '8a4861f6-cb21-4b63-a8a9-30ab5ef97d43', 'account_id': 'cultpass', 'user_id': 'b7e878b9-2ae4-4376-8489-45ecc125d068', 'channel': 'email', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '0210a4e9-c32f-46b0-9756-63c10df03953', 'account_id': 'cultpass', 'user_id': '33dd72f9-572b-4b31-9b1c-a00d92cbd435', 'channel': 'web', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'a406455a-d7f0-44a2-a1cc-18f3bb2f21ca', 'account_id': 'cultpass', 'user_id': '0287d1da-ac24-42e7-8316-07257fa651b8', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'a525c713-7c8e-4cae-9a30-94287c257177', 'account_id': 'cultpass', 'user_id': '68dc5b6b-c714-45fc-8c1e-1ccd08eebbde', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '1d79b94a-fb91-4478-8a0c-77d0391b56ba', 'account_id': 'cultpass', 'user_id': '12331d0d-e77f-476d-b8d9-934abd493a5a', 'channel': 'email', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': 'b91c28d0-8323-4dea-af3f-d8d5aaf05197', 'account_id': 'cultpass', 'user_id': '8adc35a8-bc40-406c-85a6-ec5309c123ee', 'channel': 'web', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '2e486748-0aa3-4236-a707-ce23f4045221', 'account_id': 'cultpass', 'user_id': '90ac996a-275c-441a-9ba3-8cb164bebf7e', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '60317982-a682-4565-8226-bd33b0b6aab1', 'account_id': 'cultpass', 'user_id': '0eade8ae-4936-40e5-9c16-80f6ca5bbc59', 'channel': 'email', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '89057b01-61da-4413-b440-00bf432a6740', 'account_id': 'cultpass', 'user_id': '9af24f63-4af0-49d4-a0f5-e633077ea39e', 'channel': 'web', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '65e0a350-6371-4004-b3dd-4181c42d817b', 'account_id': 'cultpass', 'user_id': '4f524da7-825b-42ec-8a9a-20ecb6ac4879', 'channel': 'chat', 'created_at': '2026-05-27 21:27:07'}
#   {'ticket_id': '739493bc-3f6e-4b34-80a0-e8e94cf92360', 'account_id': 'cultpass', 'user_id': 'f5fd5b96-425a-4bdc-83bd-202faa3ac5cf', 'channel': 'email', 'created_at': '2026-05-27 21:27:07'}
#
# === TABLE: users ===
# Columns:
#   - name=user_id, type=VARCHAR, notnull=1, pk=1
#   - name=account_id, type=VARCHAR, notnull=1, pk=0
#   - name=external_user_id, type=VARCHAR, notnull=1, pk=0
#   - name=user_name, type=VARCHAR, notnull=1, pk=0
#   - name=created_at, type=DATETIME, notnull=0, pk=0
#   - name=updated_at, type=DATETIME, notnull=0, pk=0
# Rows:
#   {'user_id': 'b953ccbf-a292-420c-a3c3-918edf5b7d0f', 'account_id': 'cultpass', 'external_user_id': 'a4ab87', 'user_name': 'Alice Kingsley', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '862f59d9-987b-4bb3-bfe2-cfa16e3633d2', 'account_id': 'cultpass', 'external_user_id': 'f556c0', 'user_name': 'Bob Stone', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '910170dc-b46a-4400-a3e6-6f77c0c556bc', 'account_id': 'cultpass', 'external_user_id': '88382b', 'user_name': 'Cathy Bloom', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '7f432978-c27a-474b-a0c8-664a36d06ffc', 'account_id': 'cultpass', 'external_user_id': '888fb2', 'user_name': 'David Noir', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': 'ac57e665-bc84-4c9d-970d-e175ae9a45f9', 'account_id': 'cultpass', 'external_user_id': 'f1f10d', 'user_name': 'Eva Green', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': 'd35af443-1fe5-465e-94f6-bb89b16f21af', 'account_id': 'cultpass', 'external_user_id': 'e6376d', 'user_name': 'Frank Ocean', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '14f61f67-27be-427e-9bf4-361ed15f01bf', 'account_id': 'cultpass', 'external_user_id': 'b7c921', 'user_name': 'Grace Hollow', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': 'd8733fe0-7b8a-4cce-b956-e16b3d74dd75', 'account_id': 'cultpass', 'external_user_id': 'c3d442', 'user_name': 'Henry Vale', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': 'ecd8defc-bf7f-437f-90be-e092f977d0b2', 'account_id': 'cultpass', 'external_user_id': 'd8e113', 'user_name': 'Isla Frost', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': 'b7e878b9-2ae4-4376-8489-45ecc125d068', 'account_id': 'cultpass', 'external_user_id': 'e2f774', 'user_name': 'Jack Mercer', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '33dd72f9-572b-4b31-9b1c-a00d92cbd435', 'account_id': 'cultpass', 'external_user_id': 'f9a305', 'user_name': 'Kara Fields', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '0287d1da-ac24-42e7-8316-07257fa651b8', 'account_id': 'cultpass', 'external_user_id': 'a1d556', 'user_name': 'Liam Cross', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '68dc5b6b-c714-45fc-8c1e-1ccd08eebbde', 'account_id': 'cultpass', 'external_user_id': 'b2e667', 'user_name': 'Maya Rivers', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '12331d0d-e77f-476d-b8d9-934abd493a5a', 'account_id': 'cultpass', 'external_user_id': 'c4f778', 'user_name': 'Noah Slate', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '8adc35a8-bc40-406c-85a6-ec5309c123ee', 'account_id': 'cultpass', 'external_user_id': 'd5a889', 'user_name': 'Olivia Hart', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '90ac996a-275c-441a-9ba3-8cb164bebf7e', 'account_id': 'cultpass', 'external_user_id': 'e6b990', 'user_name': 'Paul Ember', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '0eade8ae-4936-40e5-9c16-80f6ca5bbc59', 'account_id': 'cultpass', 'external_user_id': 'f7c101', 'user_name': 'Quinn Lake', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '9af24f63-4af0-49d4-a0f5-e633077ea39e', 'account_id': 'cultpass', 'external_user_id': 'a8d212', 'user_name': 'Ruby Lane', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': '4f524da7-825b-42ec-8a9a-20ecb6ac4879', 'account_id': 'cultpass', 'external_user_id': 'b9e323', 'user_name': 'Sam Wilder', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
#   {'user_id': 'f5fd5b96-425a-4bdc-83bd-202faa3ac5cf', 'account_id': 'cultpass', 'external_user_id': 'cad434', 'user_name': 'Tina Brooks', 'created_at': '2026-05-27 21:27:07', 'updated_at': '2026-05-27 21:27:07'}
